# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LiquidMercury-tech/ML-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I am assigning an 'engagement opportunity score' to each page then rank them by that score. So it's a ranking and scoring problem

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
#  Engagement opportunity (defined rule)
# I'm flagging pages with lower CTR relative to pages in the same position tier.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Metric: Precision@30 (Out of 30 pages I rank, how many actually have lower engagement for their position.)
# Target >=0.65(at least 65 percent of data should be legitimate opportunities.)

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

# Navigate to repo root if needed
while not os.path.isdir("data/raw") and os.getcwd() != "/":
    os.chdir("..")
import pandas as pd
df=pd.read_csv('data/raw/content_refresh_anonymized.csv')
print(f" Shape : {df.shape}")
# Out:
#  Shape : (30000, 44)

# %%
print(df[['content_id', 'client_id', 'ctr', 'avg_position',
          'engagement_rate', 'search_volume', 'impressions_90d',
          'sessions_90d', 'trend_direction']].head(10))

print(f"\nKey stats for CTR/Engagement lane:")
print(f"  Total pages: {len(df)}")
print(f"  Clients: {df['client_id'].nunique()}")
print(f"  CTR range: {df['ctr'].min():.2f}% – {df['ctr'].max():.2f}%")
print(f"  Avg position range: {df['avg_position'].min():.1f} – {df['avg_position'].max():.1f}")
print(f"  Engagement rate range: {df['engagement_rate'].min():.2f}% – {df['engagement_rate'].max():.2f}%")
print(f"\nPages with declining trend (target): {(df['trend_direction'] == 'down').sum()}")
# Out:
#              content_id          client_id   ctr  avg_position  \
# 0  content_304f48230142  client_f369cb89fc  0.76          10.6
# 1  content_a1fb4e703a9e  client_4e07408562  0.05          20.3
# 2  content_9aa793d4d895  client_7f2253d7e2  0.09          36.5
# 3  content_331d6c4de07b  client_19581e27de  0.49           6.2
# 4  content_d99b7a2d90ca  client_3fdba35f04  0.13          44.0
# 5  content_d4084a4bc775  client_f369cb89fc  0.03           8.5
# 6  content_9a34b442b552  client_8722616204  0.00           7.0
# 7  content_a63219c6e95a  client_19581e27de  0.06          21.2
# 8  content_5e6c160719bc  client_6208ef0f77  0.09          46.0
# 9  content_c27558df2b0c  client_19581e27de  0.16           4.9
#
#    engagement_rate  search_volume  impressions_90d  sessions_90d  \
# 0             5.88           10.0             3803            17
# 1             0.00           90.0            15320             9
# 2             0.00            0.0            12581            11
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# a simple fixed rule works when all the pages have same potential ctr, similar volume and content type as well as engagement rate. There is also a lack of clear threshold definition for us to apply simple if-statement here. The data is too messy for if-else statements and hence we require ML here.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
